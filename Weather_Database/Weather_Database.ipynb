# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd

# %%
import time
from datetime import datetime

# %%
from config import g_key

# %%
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)
# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['cockburn harbour', 'tsihombe', 'umzimvubu', 'bluff', 'bredasdorp', 'male', 'rikitea', 'albany', 'kapaa', 'hermanus'] Generate 776

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 2 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | male
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | cameta
# Processing Record 13 of Set 1 | gushikawa
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | peterhead
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | xam nua
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | la ronge
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | danville
# Processing Record 24 of Set 1 | pangnirtung
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | lompoc
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 1 | miranda de ebro
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | kholm-zhirkovskiy
# Processing Record 35 of Set 1 | poum
# Processing Record 36 of Set 1 | abnub
# Processing Record 37 of Set 1 | yaring
# Processing Record 38 of Set 1 | sesheke
# Processing Record 39 of Set 1 | jiangyou
# Processing Record 40 of Set 1 | deer lake
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | juneau
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | nouadhibou
# Processing Record 49 of Set 1 | vostok
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | vila franca do campo
# Processing Record 3 of Set 2 | rawah
# Processing Record 4 of Set 2 | ishikari
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | kalashnikovo
# Processing Record 8 of Set 2 | katsuura
# Processing Record 9 of Set 2 | ulagan
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | santiago de cao
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | tiznit
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | alora
# Processing Record 16 of Set 2 | najran
# Processing Record 17 of Set 2 | quatre cocos
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | huty
# Processing Record 21 of Set 2 | meulaboh
# Processing Record 22 of Set 2 | gazli
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | tura
# Processing Record 25 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | mushie
# Processing Record 29 of Set 2 | kloulklubed
# Processing Record 30 of Set 2 | batagay
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | cairns
# Processing Record 33 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 2 | mudyuga
# City not found. Skipping...
# Processing Record 35 of Set 2 | severodvinsk
# Processing Record 36 of Set 2 | mackay
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | benavente
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | puerto escondido
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | kristinehamn
# Processing Record 44 of Set 2 | duz
# City not found. Skipping...
# Processing Record 45 of Set 2 | douglas
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | oranjestad
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | teya
# Processing Record 1 of Set 3 | daru
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | luganville
# Processing Record 7 of Set 3 | bilibino
# Processing Record 8 of Set 3 | buala
# Processing Record 9 of Set 3 | sibolga
# Processing Record 10 of Set 3 | baijiantan
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | vrangel
# Processing Record 13 of Set 3 | itarema
# Processing Record 14 of Set 3 | karangasem
# Processing Record 15 of Set 3 | montego bay
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | caravelas
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | abakaliki
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | pendleton
# Processing Record 23 of Set 3 | mincivan
# Processing Record 24 of Set 3 | cumana
# Processing Record 25 of Set 3 | palmer
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | mount isa
# Processing Record 28 of Set 3 | anadyr
# Processing Record 29 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 3 | mestia
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | toulepleu
# City not found. Skipping...
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | thomaston
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | urucui
# Processing Record 38 of Set 3 | shubarshi
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | lakhnadon
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | debre sina
# Processing Record 44 of Set 3 | husavik
# Processing Record 45 of Set 3 | buraydah
# Processing Record 46 of Set 3 | dakar
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | karangampel
# Processing Record 49 of Set 3 | thinadhoo
# Processing Record 50 of Set 3 | mhlambanyatsi
# Processing Record 1 of Set 4 | nossa senhora da gloria
# Processing Record 2 of Set 4 | kigali
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | la ciotat
# Processing Record 5 of Set 4 | caucaia
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | san vicente
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | bereda
# Processing Record 11 of Set 4 | flin flon
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | san angelo
# Processing Record 15 of Set 4 | coihaique
# Processing Record 16 of Set 4 | yerbogachen
# Processing Record 17 of Set 4 | christchurch
# Processing Record 18 of Set 4 | hoi an
# Processing Record 19 of Set 4 | harper
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | geraldton
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | thaba-tseka
# Processing Record 26 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | bajram curri
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | bogalusa
# Processing Record 32 of Set 4 | kadoma
# Processing Record 33 of Set 4 | zhovtneve
# Processing Record 34 of Set 4 | salinas
# Processing Record 35 of Set 4 | mount gambier
# Processing Record 36 of Set 4 | watertown
# Processing Record 37 of Set 4 | qaanaaq
# Processing Record 38 of Set 4 | sioux lookout
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | rio grande
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | walvis bay
# Processing Record 43 of Set 4 | ornskoldsvik
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 4 | richards bay
# Processing Record 47 of Set 4 | kamina
# Processing Record 48 of Set 4 | boundiali
# Processing Record 49 of Set 4 | saint-philippe
# Processing Record 50 of Set 4 | belaya gora
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | mehamn
# Processing Record 4 of Set 5 | galveston
# Processing Record 5 of Set 5 | rio gallegos
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | rock sound
# Processing Record 8 of Set 5 | muros
# Processing Record 9 of Set 5 | nanortalik
# Processing Record 10 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 5 | riyadh
# Processing Record 12 of Set 5 | panama city
# Processing Record 13 of Set 5 | weiser
# Processing Record 14 of Set 5 | dzhebariki-khaya
# Processing Record 15 of Set 5 | port augusta
# Processing Record 16 of Set 5 | isangel
# Processing Record 17 of Set 5 | nha trang
# Processing Record 18 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 5 | havre-saint-pierre
# Processing Record 20 of Set 5 | celestun
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | biltine
# Processing Record 23 of Set 5 | pisco
# Processing Record 24 of Set 5 | tautira
# Processing Record 25 of Set 5 | baruun-urt
# Processing Record 26 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 5 | wenling
# Processing Record 28 of Set 5 | avera
# Processing Record 29 of Set 5 | whitstable
# Processing Record 30 of Set 5 | ahipara
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | nauchnyy gorodok
# Processing Record 33 of Set 5 | severo-kurilsk
# Processing Record 34 of Set 5 | moyo
# Processing Record 35 of Set 5 | xichang
# Processing Record 36 of Set 5 | northam
# Processing Record 37 of Set 5 | frolovo
# Processing Record 38 of Set 5 | griffith
# Processing Record 39 of Set 5 | haapiti
# Processing Record 40 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 5 | lasa
# Processing Record 42 of Set 5 | el faiyum
# City not found. Skipping...
# Processing Record 43 of Set 5 | hobyo
# Processing Record 44 of Set 5 | rawson
# Processing Record 45 of Set 5 | senanga
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | port hardy
# Processing Record 48 of Set 5 | bentiu
# Processing Record 49 of Set 5 | ye
# City not found. Skipping...
# Processing Record 50 of Set 5 | butembo
# Processing Record 1 of Set 6 | ponferrada
# Processing Record 2 of Set 6 | gravdal
# Processing Record 3 of Set 6 | tasiilaq
# Processing Record 4 of Set 6 | bom jesus
# Processing Record 5 of Set 6 | moree
# Processing Record 6 of Set 6 | talnakh
# Processing Record 7 of Set 6 | victoria
# Processing Record 8 of Set 6 | tazmalt
# Processing Record 9 of Set 6 | ebnat-kappel
# Processing Record 10 of Set 6 | padang
# Processing Record 11 of Set 6 | tomatlan
# Processing Record 12 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 6 | ribeira grande
# Processing Record 14 of Set 6 | chakrata
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | mulchen
# Processing Record 17 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 6 | nanao
# Processing Record 19 of Set 6 | ambanja
# Processing Record 20 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 6 | mujiayingzi
# Processing Record 22 of Set 6 | deputatskiy
# Processing Record 23 of Set 6 | ville-marie
# Processing Record 24 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 6 | brentwood
# Processing Record 26 of Set 6 | kitwe
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | lianzhou
# Processing Record 29 of Set 6 | ponta delgada
# Processing Record 30 of Set 6 | faanui
# Processing Record 31 of Set 6 | fortuna
# Processing Record 32 of Set 6 | jinsha
# Processing Record 33 of Set 6 | jalu
# Processing Record 34 of Set 6 | lincoln
# Processing Record 35 of Set 6 | norman wells
# Processing Record 36 of Set 6 | atambua
# Processing Record 37 of Set 6 | china
# Processing Record 38 of Set 6 | natal
# Processing Record 39 of Set 6 | kupang
# Processing Record 40 of Set 6 | siavonga
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | bolgatanga
# Processing Record 43 of Set 6 | necochea
# Processing Record 44 of Set 6 | dunedin
# Processing Record 45 of Set 6 | marsa matruh
# Processing Record 46 of Set 6 | los llanos de aridane
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | barranca
# Processing Record 49 of Set 6 | varzob
# Processing Record 50 of Set 6 | miranda
# Processing Record 1 of Set 7 | basco
# Processing Record 2 of Set 7 | wageningen
# Processing Record 3 of Set 7 | khandbari
# Processing Record 4 of Set 7 | yulara
# Processing Record 5 of Set 7 | ngunguru
# Processing Record 6 of Set 7 | manta
# Processing Record 7 of Set 7 | fukue
# Processing Record 8 of Set 7 | sorland
# Processing Record 9 of Set 7 | rangapara
# Processing Record 10 of Set 7 | yurimaguas
# Processing Record 11 of Set 7 | kaliua
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | fairbanks
# Processing Record 14 of Set 7 | garm
# City not found. Skipping...
# Processing Record 15 of Set 7 | bac lieu
# Processing Record 16 of Set 7 | araouane
# Processing Record 17 of Set 7 | kharan
# Processing Record 18 of Set 7 | kushmurun
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | ilhabela
# Processing Record 21 of Set 7 | linxia
# Processing Record 22 of Set 7 | guangyuan
# Processing Record 23 of Set 7 | ikom
# Processing Record 24 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | buta
# Processing Record 26 of Set 7 | casas grandes
# Processing Record 27 of Set 7 | deniliquin
# Processing Record 28 of Set 7 | upernavik
# Processing Record 29 of Set 7 | luorong
# Processing Record 30 of Set 7 | rosarito
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | lethem
# Processing Record 33 of Set 7 | zheleznogorsk
# Processing Record 34 of Set 7 | sinnamary
# Processing Record 35 of Set 7 | san carlos de bariloche
# Processing Record 36 of Set 7 | belyy yar
# Processing Record 37 of Set 7 | atar
# Processing Record 38 of Set 7 | katha
# City not found. Skipping...
# Processing Record 39 of Set 7 | la gaulette
# City not found. Skipping...
# Processing Record 40 of Set 7 | svay rieng
# Processing Record 41 of Set 7 | waitara
# Processing Record 42 of Set 7 | tutoia
# Processing Record 43 of Set 7 | bam
# Processing Record 44 of Set 7 | san patricio
# Processing Record 45 of Set 7 | saskylakh
# Processing Record 46 of Set 7 | half moon bay
# Processing Record 47 of Set 7 | eyl
# Processing Record 48 of Set 7 | harlingen
# Processing Record 49 of Set 7 | arman
# Processing Record 50 of Set 7 | zhigansk
# Processing Record 1 of Set 8 | luderitz
# Processing Record 2 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 8 | ojinaga
# Processing Record 4 of Set 8 | northallerton
# Processing Record 5 of Set 8 | along
# Processing Record 6 of Set 8 | melur
# Processing Record 7 of Set 8 | bengkulu
# Processing Record 8 of Set 8 | koumra
# Processing Record 9 of Set 8 | mapiripan
# Processing Record 10 of Set 8 | shimoda
# Processing Record 11 of Set 8 | broome
# Processing Record 12 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 8 | raga
# Processing Record 14 of Set 8 | jumla
# Processing Record 15 of Set 8 | baykit
# Processing Record 16 of Set 8 | korla
# Processing Record 17 of Set 8 | whitehorse
# Processing Record 18 of Set 8 | eureka
# Processing Record 19 of Set 8 | coahuayana
# Processing Record 20 of Set 8 | gao
# Processing Record 21 of Set 8 | aklavik
# Processing Record 22 of Set 8 | sur
# Processing Record 23 of Set 8 | lunguletu
# Processing Record 24 of Set 8 | horta
# Processing Record 25 of Set 8 | coquimbo
# Processing Record 26 of Set 8 | volzhskiy
# Processing Record 27 of Set 8 | phimai
# Processing Record 28 of Set 8 | portland
# Processing Record 29 of Set 8 | termoli
# Processing Record 30 of Set 8 | progreso
# Processing Record 31 of Set 8 | hervey bay
# Processing Record 32 of Set 8 | komsomolskiy
# Processing Record 33 of Set 8 | salalah
# Processing Record 34 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | amahai
# Processing Record 36 of Set 8 | srednekolymsk
# Processing Record 37 of Set 8 | waitati
# Processing Record 38 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 8 | nakhon phanom
# Processing Record 40 of Set 8 | krasnokamensk
# Processing Record 41 of Set 8 | soyo
# Processing Record 42 of Set 8 | korhogo
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | zubtsov
# Processing Record 45 of Set 8 | zanatepec
# City not found. Skipping...
# Processing Record 46 of Set 8 | sept-iles
# Processing Record 47 of Set 8 | doha
# Processing Record 48 of Set 8 | isla mujeres
# Processing Record 49 of Set 8 | nouakchott
# Processing Record 50 of Set 8 | amapa
# Processing Record 1 of Set 9 | longyearbyen
# Processing Record 2 of Set 9 | jadu
# Processing Record 3 of Set 9 | fort nelson
# Processing Record 4 of Set 9 | villa maria
# Processing Record 5 of Set 9 | sitka
# Processing Record 6 of Set 9 | bonthe
# Processing Record 7 of Set 9 | burica
# City not found. Skipping...
# Processing Record 8 of Set 9 | tilichiki
# Processing Record 9 of Set 9 | dwarka
# Processing Record 10 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 9 | west bay
# Processing Record 12 of Set 9 | tsabong
# Processing Record 13 of Set 9 | masindi
# Processing Record 14 of Set 9 | miragoane
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | moreira sales
# Processing Record 17 of Set 9 | bor
# Processing Record 18 of Set 9 | bathsheba
# Processing Record 19 of Set 9 | wittingen
# Processing Record 20 of Set 9 | westport
# Processing Record 21 of Set 9 | zeya
# Processing Record 22 of Set 9 | dorado
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | dekar
# Processing Record 25 of Set 9 | ixtapa
# Processing Record 26 of Set 9 | santa rosa
# Processing Record 27 of Set 9 | cururupu
# Processing Record 28 of Set 9 | caidian
# Processing Record 29 of Set 9 | mercedes
# Processing Record 30 of Set 9 | sao filipe
# Processing Record 31 of Set 9 | nelson bay
# Processing Record 32 of Set 9 | zhezkazgan
# Processing Record 33 of Set 9 | alugan
# Processing Record 34 of Set 9 | altay
# Processing Record 35 of Set 9 | uyuni
# Processing Record 36 of Set 9 | okha
# Processing Record 37 of Set 9 | mnogovershinnyy
# Processing Record 38 of Set 9 | tucurui
# Processing Record 39 of Set 9 | aswan
# Processing Record 40 of Set 9 | mazatlan
# Processing Record 41 of Set 9 | diego de almagro
# Processing Record 42 of Set 9 | grand baie
# Processing Record 43 of Set 9 | dali
# Processing Record 44 of Set 9 | asha
# Processing Record 45 of Set 9 | tuatapere
# Processing Record 46 of Set 9 | ulladulla
# Processing Record 47 of Set 9 | sistranda
# Processing Record 48 of Set 9 | denia
# Processing Record 49 of Set 9 | kostino
# Processing Record 50 of Set 9 | otradnoye
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 2 of Set 10 | bukachacha
# Processing Record 3 of Set 10 | chumikan
# Processing Record 4 of Set 10 | sungaipenuh
# Processing Record 5 of Set 10 | kaeo
# Processing Record 6 of Set 10 | te anau
# Processing Record 7 of Set 10 | mahibadhoo
# Processing Record 8 of Set 10 | boddam
# Processing Record 9 of Set 10 | nhulunbuy
# Processing Record 10 of Set 10 | pyay
# Processing Record 11 of Set 10 | qasigiannguit
# Processing Record 12 of Set 10 | turayf
# Processing Record 13 of Set 10 | satipo
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | codrington
# Processing Record 16 of Set 10 | hirara
# Processing Record 17 of Set 10 | qaqortoq
# Processing Record 18 of Set 10 | quang ngai
# Processing Record 19 of Set 10 | okulovka
# Processing Record 20 of Set 10 | clyde river
# Processing Record 21 of Set 10 | ishigaki
# Processing Record 22 of Set 10 | evanston
# Processing Record 23 of Set 10 | saint-augustin
# Processing Record 24 of Set 10 | ozernovskiy
# Processing Record 25 of Set 10 | kasama
# Processing Record 26 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 10 | sabang
# Processing Record 28 of Set 10 | banjarmasin
# Processing Record 29 of Set 10 | balikpapan
# Processing Record 30 of Set 10 | isla vista
# Processing Record 31 of Set 10 | jaisinghnagar
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | shalakusha
# Processing Record 34 of Set 10 | marienburg
# Processing Record 35 of Set 10 | banjar
# Processing Record 36 of Set 10 | santa cruz de tenerife
# Processing Record 37 of Set 10 | partizansk
# Processing Record 38 of Set 10 | kajaani
# Processing Record 39 of Set 10 | rongcheng
# Processing Record 40 of Set 10 | redlands
# Processing Record 41 of Set 10 | tarma
# Processing Record 42 of Set 10 | eskil
# Processing Record 43 of Set 10 | sibiti
# Processing Record 44 of Set 10 | ler
# Processing Record 45 of Set 10 | muravlenko
# Processing Record 46 of Set 10 | kaduna
# Processing Record 47 of Set 10 | clonakilty
# Processing Record 48 of Set 10 | alpena
# Processing Record 49 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 10 | iskateley
# Processing Record 1 of Set 11 | ambon
# Processing Record 2 of Set 11 | poykovskiy
# Processing Record 3 of Set 11 | suhaia
# Processing Record 4 of Set 11 | peschanokopskoye
# Processing Record 5 of Set 11 | port hawkesbury
# Processing Record 6 of Set 11 | barcelona
# Processing Record 7 of Set 11 | bambanglipuro
# Processing Record 8 of Set 11 | ouallam
# Processing Record 9 of Set 11 | dawlatabad
# Processing Record 10 of Set 11 | cockburn town
# Processing Record 11 of Set 11 | maykor
# Processing Record 12 of Set 11 | abha
# Processing Record 13 of Set 11 | maxixe
# Processing Record 14 of Set 11 | urayasu
# Processing Record 15 of Set 11 | nchelenge
# Processing Record 16 of Set 11 | tevaitoa
# Processing Record 17 of Set 11 | xining
# Processing Record 18 of Set 11 | marsh harbour
# Processing Record 19 of Set 11 | karakol
# Processing Record 20 of Set 11 | kavieng
# Processing Record 21 of Set 11 | omsukchan
# Processing Record 22 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 11 | port macquarie
# Processing Record 24 of Set 11 | hagere hiywet
# Processing Record 25 of Set 11 | ajdabiya
# Processing Record 26 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 27 of Set 11 | gold coast
# Processing Record 28 of Set 11 | beyneu
# Processing Record 29 of Set 11 | prachuap khiri khan
# Processing Record 30 of Set 11 | somanda
# Processing Record 31 of Set 11 | imeni poliny osipenko
# Processing Record 32 of Set 11 | henties bay
# Processing Record 33 of Set 11 | lata
# Processing Record 34 of Set 11 | goderich
# Processing Record 35 of Set 11 | mizdah
# Processing Record 36 of Set 11 | vestmannaeyjar
# Processing Record 37 of Set 11 | lorengau
# Processing Record 38 of Set 11 | ponto novo
# Processing Record 39 of Set 11 | furano
# Processing Record 40 of Set 11 | egvekinot
# Processing Record 41 of Set 11 | pando
# Processing Record 42 of Set 11 | antofagasta
# Processing Record 43 of Set 11 | afsin
# Processing Record 44 of Set 11 | honningsvag
# Processing Record 45 of Set 11 | makinsk
# Processing Record 46 of Set 11 | ola
# Processing Record 47 of Set 11 | chegdomyn
# Processing Record 48 of Set 11 | fiumicino
# Processing Record 49 of Set 11 | tancheng
# Processing Record 50 of Set 11 | myaundzha
# Processing Record 1 of Set 12 | biak
# Processing Record 2 of Set 12 | san jose
# Processing Record 3 of Set 12 | gwembe
# Processing Record 4 of Set 12 | greenwood
# Processing Record 5 of Set 12 | kota tinggi
# Processing Record 6 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 7 of Set 12 | sao joao da barra
# Processing Record 8 of Set 12 | teeli
# Processing Record 9 of Set 12 | luoyang
# Processing Record 10 of Set 12 | kemise
# Processing Record 11 of Set 12 | barra
# Processing Record 12 of Set 12 | mokolo
# Processing Record 13 of Set 12 | cayenne
# Processing Record 14 of Set 12 | nahariyya
# Processing Record 15 of Set 12 | verkhoyansk
# Processing Record 16 of Set 12 | melekhovskaya
# City not found. Skipping...
# Processing Record 17 of Set 12 | sile
# Processing Record 18 of Set 12 | tagusao
# Processing Record 19 of Set 12 | wetaskiwin
# Processing Record 20 of Set 12 | tete
# Processing Record 21 of Set 12 | shenjiamen
# Processing Record 22 of Set 12 | ketchikan
# Processing Record 23 of Set 12 | kandi
# Processing Record 24 of Set 12 | beloha
# Processing Record 25 of Set 12 | gat
# Processing Record 26 of Set 12 | abu kamal
# Processing Record 27 of Set 12 | kiunga
# Processing Record 28 of Set 12 | ruvo di puglia
# Processing Record 29 of Set 12 | tuensang
# Processing Record 30 of Set 12 | pangody
# Processing Record 31 of Set 12 | tisul
# Processing Record 32 of Set 12 | watsa
# Processing Record 33 of Set 12 | vangaindrano
# Processing Record 34 of Set 12 | launceston
# Processing Record 35 of Set 12 | hilliard
# Processing Record 36 of Set 12 | kokopo
# Processing Record 37 of Set 12 | bagdarin
# Processing Record 38 of Set 12 | anuradhapura
# Processing Record 39 of Set 12 | mandalgovi
# Processing Record 40 of Set 12 | rorvik
# Processing Record 41 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 12 | tecoanapa
# Processing Record 43 of Set 12 | port moresby
# Processing Record 44 of Set 12 | alta floresta
# Processing Record 45 of Set 12 | shangrao
# Processing Record 46 of Set 12 | balingasay
# Processing Record 47 of Set 12 | berlevag
# Processing Record 48 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 12 | medeiros neto
# Processing Record 50 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 1 of Set 13 | mayo
# Processing Record 2 of Set 13 | norden
# Processing Record 3 of Set 13 | puerto el triunfo
# Processing Record 4 of Set 13 | staroutkinsk
# Processing Record 5 of Set 13 | khovu-aksy
# Processing Record 6 of Set 13 | cheremukhovo
# Processing Record 7 of Set 13 | maniitsoq
# Processing Record 8 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 13 | simplicio mendes
# Processing Record 10 of Set 13 | grindavik
# Processing Record 11 of Set 13 | chicama
# Processing Record 12 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 13 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 13 | rotifunk
# Processing Record 15 of Set 13 | los palacios
# Processing Record 16 of Set 13 | chor
# Processing Record 17 of Set 13 | santa marta
# Processing Record 18 of Set 13 | ucluelet
# Processing Record 19 of Set 13 | turan
# Processing Record 20 of Set 13 | taoudenni
# Processing Record 21 of Set 13 | abu samrah
# Processing Record 22 of Set 13 | gboko
# Processing Record 23 of Set 13 | port blair
# Processing Record 24 of Set 13 | arandis
# Processing Record 25 of Set 13 | acapulco
# Processing Record 26 of Set 13 | hudson bay
# Processing Record 27 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 13 | vilhena
# Processing Record 29 of Set 13 | vaitape
# Processing Record 30 of Set 13 | grindsted
# Processing Record 31 of Set 13 | iracoubo
# Processing Record 32 of Set 13 | puerto cabezas
# Processing Record 33 of Set 13 | barcelos
# Processing Record 34 of Set 13 | pula
# Processing Record 35 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 13 | lengshuitan
# Processing Record 37 of Set 13 | la uribe
# City not found. Skipping...
# Processing Record 38 of Set 13 | yarmouth
# Processing Record 39 of Set 13 | prudyanka
# Processing Record 40 of Set 13 | ugoofaaru
# Processing Record 41 of Set 13 | sillod
# Processing Record 42 of Set 13 | mishelevka
# Processing Record 43 of Set 13 | galeana
# Processing Record 44 of Set 13 | issoire
# Processing Record 45 of Set 13 | katobu
# Processing Record 46 of Set 13 | mikkeli
# Processing Record 47 of Set 13 | dahuk
# Processing Record 48 of Set 13 | sasovo
# Processing Record 49 of Set 13 | utraula
# Processing Record 50 of Set 13 | kenora
# Processing Record 1 of Set 14 | dutse
# Processing Record 2 of Set 14 | semirom
# Processing Record 3 of Set 14 | zabol
# Processing Record 4 of Set 14 | rakhya
# City not found. Skipping...
# Processing Record 5 of Set 14 | namtsy
# Processing Record 6 of Set 14 | lima
# Processing Record 7 of Set 14 | adeje
# Processing Record 8 of Set 14 | torbat-e jam
# Processing Record 9 of Set 14 | oktyabrskoye
# Processing Record 10 of Set 14 | swakopmund
# Processing Record 11 of Set 14 | tansen
# Processing Record 12 of Set 14 | taree
# Processing Record 13 of Set 14 | lira
# Processing Record 14 of Set 14 | bara
# Processing Record 15 of Set 14 | kimbe
# Processing Record 16 of Set 14 | mocuba
# Processing Record 17 of Set 14 | belen
# Processing Record 18 of Set 14 | raudeberg
# Processing Record 19 of Set 14 | merauke
# Processing Record 20 of Set 14 | baculin
# Processing Record 21 of Set 14 | ossora
# Processing Record 22 of Set 14 | matara
# Processing Record 23 of Set 14 | tsiroanomandidy
# Processing Record 24 of Set 14 | hammerfest
# Processing Record 25 of Set 14 | davidson
# Processing Record 26 of Set 14 | kirensk
# Processing Record 27 of Set 14 | gorontalo
# Processing Record 28 of Set 14 | leh
# Processing Record 29 of Set 14 | viedma
# Processing Record 30 of Set 14 | waipawa
# Processing Record 31 of Set 14 | crixas
# Processing Record 32 of Set 14 | ulaangom
# Processing Record 33 of Set 14 | tambun
# Processing Record 34 of Set 14 | high level
# Processing Record 35 of Set 14 | evensk
# Processing Record 36 of Set 14 | nizhniy tsasuchey
# Processing Record 37 of Set 14 | semme
# Processing Record 38 of Set 14 | ferkessedougou
# Processing Record 39 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 40 of Set 14 | methoni
# Processing Record 41 of Set 14 | tarhunah
# City not found. Skipping...
# Processing Record 42 of Set 14 | itacarambi
# Processing Record 43 of Set 14 | uniontown
# Processing Record 44 of Set 14 | blagoyevo
# Processing Record 45 of Set 14 | plainview
# Processing Record 46 of Set 14 | burnie
# Processing Record 47 of Set 14 | suffolk
# Processing Record 48 of Set 14 | kenai
# Processing Record 49 of Set 14 | flinders
# Processing Record 50 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | brigantine
# Processing Record 2 of Set 15 | powell river
# Processing Record 3 of Set 15 | hualmay
# Processing Record 4 of Set 15 | touros
# Processing Record 5 of Set 15 | raton
# Processing Record 6 of Set 15 | oeiras do para
# Processing Record 7 of Set 15 | castro-urdiales
# Processing Record 8 of Set 15 | kuandian
# Processing Record 9 of Set 15 | vigeland
# Processing Record 10 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 11 of Set 15 | campbell river
# Processing Record 12 of Set 15 | shasta lake
# Processing Record 13 of Set 15 | yar-sale
# Processing Record 14 of Set 15 | sao gabriel da cachoeira
# Processing Record 15 of Set 15 | mildura
# Processing Record 16 of Set 15 | college
# Processing Record 17 of Set 15 | corum
# Processing Record 18 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 19 of Set 15 | champasak
# Processing Record 20 of Set 15 | celendin
# Processing Record 21 of Set 15 | bobo dioulasso
# Processing Record 22 of Set 15 | kolondieba
# Processing Record 23 of Set 15 | homer
# Processing Record 24 of Set 15 | buchanan
# Processing Record 25 of Set 15 | zheleznodorozhnyy
# Processing Record 26 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 15 | decatur
# Processing Record 28 of Set 15 | kidal
# Processing Record 29 of Set 15 | medicine hat
# Processing Record 30 of Set 15 | ganzhou
# Processing Record 31 of Set 15 | trincomalee
# Processing Record 32 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 33 of Set 15 | sazonovo
# Processing Record 34 of Set 15 | burgos
# Processing Record 35 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 36 of Set 15 | presidencia roque saenz pena
# Processing Record 37 of Set 15 | golden
# Processing Record 38 of Set 15 | atlantic city
# Processing Record 39 of Set 15 | anjangaon
# Processing Record 40 of Set 15 | penzance
# Processing Record 41 of Set 15 | khandyga
# Processing Record 42 of Set 15 | farafangana
# Processing Record 43 of Set 15 | kirakira
# Processing Record 44 of Set 15 | smithers
# Processing Record 45 of Set 15 | bataipora
# Processing Record 46 of Set 15 | umm kaddadah
# Processing Record 47 of Set 15 | naze
# Processing Record 48 of Set 15 | krapivinskiy
# Processing Record 49 of Set 15 | port-de-paix
# City not found. Skipping...
# Processing Record 50 of Set 15 | awbari
# Processing Record 1 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 16 | san cristobal
# Processing Record 3 of Set 16 | ibra
# Processing Record 4 of Set 16 | kahta
# Processing Record 5 of Set 16 | sobolevo
# Processing Record 6 of Set 16 | faya
# Processing Record 7 of Set 16 | tambacounda
# Processing Record 8 of Set 16 | katsina
# Processing Record 9 of Set 16 | pandan
# Processing Record 10 of Set 16 | haines junction
# Processing Record 11 of Set 16 | sidi ali
# Processing Record 12 of Set 16 | goya
# Processing Record 13 of Set 16 | altamira
# Processing Record 14 of Set 16 | troitskoye
# Processing Record 15 of Set 16 | manggar
# Processing Record 16 of Set 16 | san andres
# Processing Record 17 of Set 16 | jacksonville
# Processing Record 18 of Set 16 | alekseyevsk
# Processing Record 19 of Set 16 | awjilah
# Processing Record 20 of Set 16 | vila velha
# Processing Record 21 of Set 16 | okhotsk
# Processing Record 22 of Set 16 | chissamba
# Processing Record 23 of Set 16 | zabaykalsk
# Processing Record 24 of Set 16 | murray bridge
# Processing Record 25 of Set 16 | kismayo
# Processing Record 26 of Set 16 | galle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bluff      NZ -46.6000  168.3333     59.81        58           9
# 1   Bredasdorp      ZA -34.5322   20.0403     68.29        96          51
# 2         Male      MV   4.1748   73.5089     81.30        65         100
# 3      Rikitea      PF -23.1203 -134.9692     79.43        68         100
# 4       Albany      US  42.6001  -73.9662     10.51        71           5
# 5        Kapaa      US  22.0752 -159.3190     78.78        71           0
# 6     Hermanus      ZA -34.4187   19.2345     71.91        89          64
# 7  Port Alfred      ZA -33.5906   26.8910     70.20        88          49
# 8       Cameta      BR  -2.2444  -49.4958     75.16        95         100
# 9    Gushikawa      JP  26.3544  127.8686     62.60        51          40
#
#    Wind Speed Current Description
# 0       11.59           clear sky
# 1        6.46       broken clouds
# 2        7.58     overcast clouds
# 3       13.71     overcast clouds
# 4        5.97           clear sky
# 5        4.00           clear sky
# 6        9.89       broken clouds
# 7       25.12    scattered clouds
# 8        3.67     overcast clouds
# 9       10.36    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
