# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd

# %%
import time
from datetime import datetime

# %%
from config import g_key

# %%
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)
# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['cidreira', 'valparaiso', 'nelson bay', 'ingraj bazar', 'new norfolk', 'lexington', 'muroto', 'burica', 'taolanaro', 'rucphen'] Generate 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | valparaiso
# Processing Record 3 of Set 1 | nelson bay
# Processing Record 4 of Set 1 | ingraj bazar
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | lexington
# Processing Record 7 of Set 1 | muroto
# Processing Record 8 of Set 1 | burica
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | rucphen
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | belen
# Processing Record 15 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | khandyga
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | nome
# Processing Record 23 of Set 1 | olinda
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | andenes
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | san patricio
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | hambantota
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | mvuma
# Processing Record 37 of Set 1 | vardo
# Processing Record 38 of Set 1 | baboua
# City not found. Skipping...
# Processing Record 39 of Set 1 | broome
# Processing Record 40 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 1 | aklavik
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | khani
# Processing Record 44 of Set 1 | cabedelo
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | moranbah
# Processing Record 48 of Set 1 | honiara
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | kichera
# Processing Record 1 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 2 of Set 2 | povenets
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 2 | penon blanco
# Processing Record 9 of Set 2 | atar
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | nouadhibou
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | misratah
# Processing Record 15 of Set 2 | kamaishi
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | srednekolymsk
# Processing Record 19 of Set 2 | steubenville
# Processing Record 20 of Set 2 | bardiyah
# Processing Record 21 of Set 2 | buraydah
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | kahului
# Processing Record 24 of Set 2 | ewa beach
# Processing Record 25 of Set 2 | port barton
# Processing Record 26 of Set 2 | kodinsk
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | mwinilunga
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | maramba
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | cody
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | rocha
# Processing Record 36 of Set 2 | tilichiki
# Processing Record 37 of Set 2 | kachug
# Processing Record 38 of Set 2 | den helder
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | santo angelo
# Processing Record 41 of Set 2 | voznesenye
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | panguna
# Processing Record 44 of Set 2 | kununurra
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | stornoway
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | adeje
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | portland
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | tessalit
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | trelew
# Processing Record 5 of Set 3 | makakilo city
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | kokuy
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | rovaniemi
# Processing Record 11 of Set 3 | luanda
# Processing Record 12 of Set 3 | divnogorsk
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | pando
# Processing Record 16 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 3 | machesney park
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | bilaspur
# Processing Record 22 of Set 3 | fiumicino
# Processing Record 23 of Set 3 | trinidad
# Processing Record 24 of Set 3 | sabha
# Processing Record 25 of Set 3 | saint-pacome
# City not found. Skipping...
# Processing Record 26 of Set 3 | vasai
# Processing Record 27 of Set 3 | saint-dizier
# Processing Record 28 of Set 3 | carballo
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | punta arenas
# Processing Record 32 of Set 3 | seminole
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | coquimbo
# Processing Record 35 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | virginia beach
# Processing Record 38 of Set 3 | palmares do sul
# Processing Record 39 of Set 3 | port blair
# Processing Record 40 of Set 3 | pachino
# Processing Record 41 of Set 3 | bathsheba
# Processing Record 42 of Set 3 | newport
# Processing Record 43 of Set 3 | soloneshnoye
# Processing Record 44 of Set 3 | sarny
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | galion
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 3 | bodden town
# Processing Record 50 of Set 3 | yumaguzino
# Processing Record 1 of Set 4 | atsiki
# City not found. Skipping...
# Processing Record 2 of Set 4 | lenoir
# Processing Record 3 of Set 4 | muriwai beach
# Processing Record 4 of Set 4 | dunedin
# Processing Record 5 of Set 4 | timra
# Processing Record 6 of Set 4 | tawang
# Processing Record 7 of Set 4 | punta alta
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | panlaitan
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | qena
# Processing Record 12 of Set 4 | labuan
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | tahoua
# Processing Record 16 of Set 4 | shimoda
# Processing Record 17 of Set 4 | roma
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | parangan
# Processing Record 20 of Set 4 | cairns
# Processing Record 21 of Set 4 | havre-saint-pierre
# Processing Record 22 of Set 4 | la palma
# Processing Record 23 of Set 4 | harper
# Processing Record 24 of Set 4 | daru
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | iskateley
# Processing Record 28 of Set 4 | adrar
# Processing Record 29 of Set 4 | orlik
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | nanakuli
# Processing Record 32 of Set 4 | liverpool
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | lincoln
# Processing Record 35 of Set 4 | lagoa
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | cape town
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | requena
# Processing Record 41 of Set 4 | hualmay
# Processing Record 42 of Set 4 | martapura
# Processing Record 43 of Set 4 | erzin
# Processing Record 44 of Set 4 | weiser
# Processing Record 45 of Set 4 | vermilion
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | talcahuano
# Processing Record 48 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 4 | montrose
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | mapiripan
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | sindand
# City not found. Skipping...
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | port macquarie
# Processing Record 9 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 5 | dudinka
# Processing Record 11 of Set 5 | san alberto
# Processing Record 12 of Set 5 | pombas
# Processing Record 13 of Set 5 | nacala
# Processing Record 14 of Set 5 | dawei
# Processing Record 15 of Set 5 | kadoma
# Processing Record 16 of Set 5 | bandarbeyla
# Processing Record 17 of Set 5 | cayenne
# Processing Record 18 of Set 5 | pacific grove
# Processing Record 19 of Set 5 | muzhi
# Processing Record 20 of Set 5 | algeciras
# Processing Record 21 of Set 5 | pacifica
# Processing Record 22 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | leshukonskoye
# Processing Record 25 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | biankouma
# Processing Record 29 of Set 5 | houlung
# City not found. Skipping...
# Processing Record 30 of Set 5 | santa fe
# Processing Record 31 of Set 5 | assai
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | banfora
# Processing Record 34 of Set 5 | agadez
# Processing Record 35 of Set 5 | tual
# Processing Record 36 of Set 5 | forio
# Processing Record 37 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 5 | middelburg
# Processing Record 39 of Set 5 | bambanglipuro
# Processing Record 40 of Set 5 | nemuro
# Processing Record 41 of Set 5 | araouane
# Processing Record 42 of Set 5 | lavrentiya
# Processing Record 43 of Set 5 | salalah
# Processing Record 44 of Set 5 | kamenka
# Processing Record 45 of Set 5 | tasiilaq
# Processing Record 46 of Set 5 | pailitas
# Processing Record 47 of Set 5 | vanimo
# Processing Record 48 of Set 5 | jieshi
# Processing Record 49 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 50 of Set 5 | vila
# Processing Record 1 of Set 6 | moroto
# Processing Record 2 of Set 6 | malinyi
# Processing Record 3 of Set 6 | cabo san lucas
# Processing Record 4 of Set 6 | manta
# Processing Record 5 of Set 6 | dengzhou
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 8 of Set 6 | alta floresta
# Processing Record 9 of Set 6 | waingapu
# Processing Record 10 of Set 6 | susanville
# Processing Record 11 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 14 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 15 of Set 6 | kapuskasing
# Processing Record 16 of Set 6 | yumen
# Processing Record 17 of Set 6 | glendive
# Processing Record 18 of Set 6 | dhidhdhoo
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | codajas
# Processing Record 21 of Set 6 | falmouth
# Processing Record 22 of Set 6 | weymouth
# Processing Record 23 of Set 6 | dauphin
# Processing Record 24 of Set 6 | saint-philippe
# Processing Record 25 of Set 6 | mount gambier
# Processing Record 26 of Set 6 | biharamulo
# Processing Record 27 of Set 6 | coruripe
# Processing Record 28 of Set 6 | chapais
# Processing Record 29 of Set 6 | vanersborg
# Processing Record 30 of Set 6 | college
# Processing Record 31 of Set 6 | saint-pierre
# Processing Record 32 of Set 6 | havoysund
# Processing Record 33 of Set 6 | linjiang
# Processing Record 34 of Set 6 | cheney
# Processing Record 35 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 37 of Set 6 | villa rica
# Processing Record 38 of Set 6 | mayumba
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | arlit
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | mombetsu
# Processing Record 43 of Set 6 | neiafu
# Processing Record 44 of Set 6 | hofn
# Processing Record 45 of Set 6 | griffith
# Processing Record 46 of Set 6 | port hardy
# Processing Record 47 of Set 6 | marawi
# Processing Record 48 of Set 6 | rayong
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | freeport
# Processing Record 1 of Set 7 | plettenberg bay
# Processing Record 2 of Set 7 | tres lagoas
# Processing Record 3 of Set 7 | birao
# Processing Record 4 of Set 7 | saskylakh
# Processing Record 5 of Set 7 | basco
# Processing Record 6 of Set 7 | zheleznodorozhnyy
# Processing Record 7 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 7 | vestmannaeyjar
# Processing Record 9 of Set 7 | humaita
# Processing Record 10 of Set 7 | sovetskiy
# Processing Record 11 of Set 7 | padang
# Processing Record 12 of Set 7 | sayyan
# Processing Record 13 of Set 7 | coihaique
# Processing Record 14 of Set 7 | batagay
# Processing Record 15 of Set 7 | ilinskiy
# Processing Record 16 of Set 7 | beringovskiy
# Processing Record 17 of Set 7 | rawson
# Processing Record 18 of Set 7 | moussoro
# Processing Record 19 of Set 7 | calimanesti
# Processing Record 20 of Set 7 | hasaki
# Processing Record 21 of Set 7 | vila franca do campo
# Processing Record 22 of Set 7 | matadi
# Processing Record 23 of Set 7 | acari
# Processing Record 24 of Set 7 | kormend
# Processing Record 25 of Set 7 | olavarria
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | eltham
# Processing Record 28 of Set 7 | miranda
# Processing Record 29 of Set 7 | kaspiyskiy
# Processing Record 30 of Set 7 | tupik
# Processing Record 31 of Set 7 | turkan
# Processing Record 32 of Set 7 | loandjili
# Processing Record 33 of Set 7 | middle valley
# Processing Record 34 of Set 7 | khatanga
# Processing Record 35 of Set 7 | geraldton
# Processing Record 36 of Set 7 | tura
# Processing Record 37 of Set 7 | semey
# Processing Record 38 of Set 7 | kasiri
# Processing Record 39 of Set 7 | zimovniki
# Processing Record 40 of Set 7 | east london
# Processing Record 41 of Set 7 | arraial do cabo
# Processing Record 42 of Set 7 | margate
# Processing Record 43 of Set 7 | saint-francois
# Processing Record 44 of Set 7 | georgiyevka
# Processing Record 45 of Set 7 | hamilton
# Processing Record 46 of Set 7 | shingu
# Processing Record 47 of Set 7 | leningradskiy
# Processing Record 48 of Set 7 | santa cruz cabralia
# Processing Record 49 of Set 7 | hami
# Processing Record 50 of Set 7 | datong
# Processing Record 1 of Set 8 | bulgan
# Processing Record 2 of Set 8 | bosaso
# Processing Record 3 of Set 8 | miri
# Processing Record 4 of Set 8 | roros
# Processing Record 5 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | manzhouli
# Processing Record 8 of Set 8 | bundaberg
# Processing Record 9 of Set 8 | bethel
# Processing Record 10 of Set 8 | ferkessedougou
# Processing Record 11 of Set 8 | kapoeta
# Processing Record 12 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 8 | itaituba
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | richards bay
# Processing Record 16 of Set 8 | te anau
# Processing Record 17 of Set 8 | nehe
# Processing Record 18 of Set 8 | yenangyaung
# Processing Record 19 of Set 8 | pangody
# Processing Record 20 of Set 8 | rancho palos verdes
# Processing Record 21 of Set 8 | presidente medici
# Processing Record 22 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 8 | ahipara
# Processing Record 24 of Set 8 | nordfjordeid
# Processing Record 25 of Set 8 | sorong
# Processing Record 26 of Set 8 | jalu
# Processing Record 27 of Set 8 | chikoy
# City not found. Skipping...
# Processing Record 28 of Set 8 | odienne
# Processing Record 29 of Set 8 | najran
# Processing Record 30 of Set 8 | mugur-aksy
# Processing Record 31 of Set 8 | alice springs
# Processing Record 32 of Set 8 | assiniboia
# Processing Record 33 of Set 8 | brae
# Processing Record 34 of Set 8 | puerto colombia
# Processing Record 35 of Set 8 | saravan
# Processing Record 36 of Set 8 | quatre cocos
# Processing Record 37 of Set 8 | jiazi
# Processing Record 38 of Set 8 | baltasi
# Processing Record 39 of Set 8 | westport
# Processing Record 40 of Set 8 | bilma
# Processing Record 41 of Set 8 | spring hill
# Processing Record 42 of Set 8 | hobyo
# Processing Record 43 of Set 8 | huarmey
# Processing Record 44 of Set 8 | kawalu
# Processing Record 45 of Set 8 | acapulco
# Processing Record 46 of Set 8 | gari
# Processing Record 47 of Set 8 | finschhafen
# Processing Record 48 of Set 8 | cassia
# Processing Record 49 of Set 8 | zaranj
# Processing Record 50 of Set 8 | kijang
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | dunmore east
# Processing Record 3 of Set 9 | greensburg
# Processing Record 4 of Set 9 | mocuba
# Processing Record 5 of Set 9 | milyutinskaya
# Processing Record 6 of Set 9 | seymchan
# Processing Record 7 of Set 9 | vanderhoof
# Processing Record 8 of Set 9 | lluta
# Processing Record 9 of Set 9 | arona
# Processing Record 10 of Set 9 | teya
# Processing Record 11 of Set 9 | ryotsu
# Processing Record 12 of Set 9 | progreso
# Processing Record 13 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | isangel
# Processing Record 15 of Set 9 | guajara-mirim
# City not found. Skipping...
# Processing Record 16 of Set 9 | dzaoudzi
# Processing Record 17 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 9 | sur
# Processing Record 19 of Set 9 | montepuez
# Processing Record 20 of Set 9 | tautira
# Processing Record 21 of Set 9 | pevek
# Processing Record 22 of Set 9 | gimli
# Processing Record 23 of Set 9 | berlevag
# Processing Record 24 of Set 9 | coahuayana
# Processing Record 25 of Set 9 | kandi
# Processing Record 26 of Set 9 | yulara
# Processing Record 27 of Set 9 | troitskoye
# Processing Record 28 of Set 9 | pisco
# Processing Record 29 of Set 9 | xihe
# Processing Record 30 of Set 9 | nisia floresta
# Processing Record 31 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 9 | oranjemund
# Processing Record 33 of Set 9 | trincomalee
# Processing Record 34 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 9 | gladstone
# Processing Record 37 of Set 9 | vadso
# Processing Record 38 of Set 9 | bontang
# Processing Record 39 of Set 9 | kudahuvadhoo
# Processing Record 40 of Set 9 | mahanoro
# Processing Record 41 of Set 9 | poronaysk
# Processing Record 42 of Set 9 | clyde river
# Processing Record 43 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 9 | aksu
# Processing Record 45 of Set 9 | jyvaskyla
# Processing Record 46 of Set 9 | zhaoyuan
# Processing Record 47 of Set 9 | port lincoln
# Processing Record 48 of Set 9 | cockburn town
# Processing Record 49 of Set 9 | karistos
# City not found. Skipping...
# Processing Record 50 of Set 9 | santo antonio do amparo
# Processing Record 1 of Set 10 | baker city
# Processing Record 2 of Set 10 | likhoslavl
# Processing Record 3 of Set 10 | aksay
# Processing Record 4 of Set 10 | mareeba
# Processing Record 5 of Set 10 | felanitx
# Processing Record 6 of Set 10 | abreus
# Processing Record 7 of Set 10 | monrovia
# Processing Record 8 of Set 10 | doha
# Processing Record 9 of Set 10 | turukhansk
# Processing Record 10 of Set 10 | kelowna
# Processing Record 11 of Set 10 | betioky
# Processing Record 12 of Set 10 | kasongo
# Processing Record 13 of Set 10 | tommot
# Processing Record 14 of Set 10 | puerto leguizamo
# Processing Record 15 of Set 10 | izvoarele sucevei
# Processing Record 16 of Set 10 | bonavista
# Processing Record 17 of Set 10 | maryborough
# Processing Record 18 of Set 10 | seoul
# Processing Record 19 of Set 10 | half moon bay
# Processing Record 20 of Set 10 | inuvik
# Processing Record 21 of Set 10 | vanavara
# Processing Record 22 of Set 10 | baykit
# Processing Record 23 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 10 | kigorobya
# Processing Record 25 of Set 10 | maningrida
# Processing Record 26 of Set 10 | corner brook
# Processing Record 27 of Set 10 | tshikapa
# Processing Record 28 of Set 10 | tacuarembo
# Processing Record 29 of Set 10 | siljan
# Processing Record 30 of Set 10 | fallon
# Processing Record 31 of Set 10 | tuy hoa
# Processing Record 32 of Set 10 | menongue
# Processing Record 33 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 10 | chipinge
# Processing Record 35 of Set 10 | camana
# Processing Record 36 of Set 10 | korla
# Processing Record 37 of Set 10 | shellbrook
# Processing Record 38 of Set 10 | grand gaube
# Processing Record 39 of Set 10 | lumeje
# Processing Record 40 of Set 10 | sao raimundo das mangabeiras
# Processing Record 41 of Set 10 | fare
# Processing Record 42 of Set 10 | dabou
# Processing Record 43 of Set 10 | sistranda
# Processing Record 44 of Set 10 | turkistan
# Processing Record 45 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 10 | mindelo
# Processing Record 47 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 10 | namtsy
# Processing Record 49 of Set 10 | klaksvik
# Processing Record 50 of Set 10 | tabas
# Processing Record 1 of Set 11 | hokitika
# Processing Record 2 of Set 11 | sosnovo-ozerskoye
# Processing Record 3 of Set 11 | san vicente
# Processing Record 4 of Set 11 | sayalgudi
# City not found. Skipping...
# Processing Record 5 of Set 11 | talnakh
# Processing Record 6 of Set 11 | qaqortoq
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | cumberland
# Processing Record 9 of Set 11 | arco
# Processing Record 10 of Set 11 | itoman
# Processing Record 11 of Set 11 | ginir
# Processing Record 12 of Set 11 | kavaratti
# Processing Record 13 of Set 11 | alappuzha
# Processing Record 14 of Set 11 | brownsville
# Processing Record 15 of Set 11 | qingdao
# Processing Record 16 of Set 11 | nioro
# Processing Record 17 of Set 11 | saint george
# Processing Record 18 of Set 11 | skibbereen
# Processing Record 19 of Set 11 | kropotkin
# Processing Record 20 of Set 11 | alexandria
# Processing Record 21 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 11 | dicabisagan
# Processing Record 23 of Set 11 | omboue
# Processing Record 24 of Set 11 | matara
# Processing Record 25 of Set 11 | kavieng
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | chengmai
# City not found. Skipping...
# Processing Record 28 of Set 11 | breves
# Processing Record 29 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 11 | san cristobal
# Processing Record 31 of Set 11 | george town
# Processing Record 32 of Set 11 | senno
# Processing Record 33 of Set 11 | bougouni
# Processing Record 34 of Set 11 | samarai
# Processing Record 35 of Set 11 | puerto del rosario
# Processing Record 36 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 11 | elk point
# Processing Record 39 of Set 11 | ondangwa
# Processing Record 40 of Set 11 | qasigiannguit
# Processing Record 41 of Set 11 | virtsu
# Processing Record 42 of Set 11 | peniche
# Processing Record 43 of Set 11 | sawtell
# Processing Record 44 of Set 11 | sao felix do xingu
# Processing Record 45 of Set 11 | guasdualito
# Processing Record 46 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 11 | lusambo
# Processing Record 48 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 11 | rantauprapat
# Processing Record 50 of Set 11 | we
# City not found. Skipping...
# Processing Record 1 of Set 12 | alyangula
# Processing Record 2 of Set 12 | sangar
# Processing Record 3 of Set 12 | tromso
# Processing Record 4 of Set 12 | meulaboh
# Processing Record 5 of Set 12 | gallup
# Processing Record 6 of Set 12 | tolaga bay
# Processing Record 7 of Set 12 | lasa
# Processing Record 8 of Set 12 | beatrice
# Processing Record 9 of Set 12 | azad shahr
# Processing Record 10 of Set 12 | guarapari
# Processing Record 11 of Set 12 | prince rupert
# Processing Record 12 of Set 12 | pemba
# Processing Record 13 of Set 12 | kasulu
# Processing Record 14 of Set 12 | jiwani
# Processing Record 15 of Set 12 | jatai
# Processing Record 16 of Set 12 | koumac
# Processing Record 17 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 12 | kalmunai
# Processing Record 20 of Set 12 | artyom
# Processing Record 21 of Set 12 | mount isa
# Processing Record 22 of Set 12 | banepa
# Processing Record 23 of Set 12 | anadyr
# Processing Record 24 of Set 12 | buluang
# Processing Record 25 of Set 12 | chicama
# Processing Record 26 of Set 12 | hovd
# Processing Record 27 of Set 12 | christchurch
# Processing Record 28 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 12 | peleduy
# Processing Record 30 of Set 12 | grand-santi
# Processing Record 31 of Set 12 | saint-augustin
# Processing Record 32 of Set 12 | quelimane
# Processing Record 33 of Set 12 | barcelos
# Processing Record 34 of Set 12 | kalengwa
# Processing Record 35 of Set 12 | sorland
# Processing Record 36 of Set 12 | asyut
# Processing Record 37 of Set 12 | narsaq
# Processing Record 38 of Set 12 | zhuanghe
# Processing Record 39 of Set 12 | tiarei
# Processing Record 40 of Set 12 | troitsko-pechorsk
# Processing Record 41 of Set 12 | tarko-sale
# Processing Record 42 of Set 12 | langsa
# Processing Record 43 of Set 12 | nyurba
# Processing Record 44 of Set 12 | yarada
# Processing Record 45 of Set 12 | krasnoselkup
# Processing Record 46 of Set 12 | nizhniy kuranakh
# Processing Record 47 of Set 12 | upernavik
# Processing Record 48 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 12 | yar-sale
# Processing Record 50 of Set 12 | beidao
# Processing Record 1 of Set 13 | auki
# Processing Record 2 of Set 13 | itapaci
# Processing Record 3 of Set 13 | honningsvag
# Processing Record 4 of Set 13 | ayagoz
# Processing Record 5 of Set 13 | sakaiminato
# Processing Record 6 of Set 13 | fairbanks
# Processing Record 7 of Set 13 | iralaya
# Processing Record 8 of Set 13 | nara
# Processing Record 9 of Set 13 | menomonie
# Processing Record 10 of Set 13 | korenovsk
# Processing Record 11 of Set 13 | pimentel
# Processing Record 12 of Set 13 | lawton
# Processing Record 13 of Set 13 | burnie
# Processing Record 14 of Set 13 | poum
# Processing Record 15 of Set 13 | pascagoula
# Processing Record 16 of Set 13 | cumana
# Processing Record 17 of Set 13 | whitehorse
# Processing Record 18 of Set 13 | mackenzie
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | amahai
# Processing Record 21 of Set 13 | maragogi
# Processing Record 22 of Set 13 | kayerkan
# Processing Record 23 of Set 13 | pueblo nuevo
# Processing Record 24 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 13 | polignano a mare
# Processing Record 26 of Set 13 | chajul
# Processing Record 27 of Set 13 | shelburne
# Processing Record 28 of Set 13 | muros
# Processing Record 29 of Set 13 | kutum
# Processing Record 30 of Set 13 | manavalakurichi
# Processing Record 31 of Set 13 | magadi
# Processing Record 32 of Set 13 | kysyl-syr
# Processing Record 33 of Set 13 | mahuva
# Processing Record 34 of Set 13 | mizdah
# Processing Record 35 of Set 13 | sindor
# Processing Record 36 of Set 13 | raudeberg
# Processing Record 37 of Set 13 | troitskiy
# Processing Record 38 of Set 13 | deputatskiy
# Processing Record 39 of Set 13 | gazli
# Processing Record 40 of Set 13 | kitui
# Processing Record 41 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 13 | honolulu
# Processing Record 43 of Set 13 | camopi
# Processing Record 44 of Set 13 | buarcos
# Processing Record 45 of Set 13 | farafangana
# Processing Record 46 of Set 13 | ixtapa
# Processing Record 47 of Set 13 | nocupetaro
# Processing Record 48 of Set 13 | hvide sande
# Processing Record 49 of Set 13 | sundumbili
# Processing Record 50 of Set 13 | okhotsk
# Processing Record 1 of Set 14 | warrington
# Processing Record 2 of Set 14 | chapada dos guimaraes
# Processing Record 3 of Set 14 | warangal
# Processing Record 4 of Set 14 | dillon
# Processing Record 5 of Set 14 | badajoz
# Processing Record 6 of Set 14 | vypolzovo
# Processing Record 7 of Set 14 | veshenskaya
# Processing Record 8 of Set 14 | luderitz
# Processing Record 9 of Set 14 | zolotonosha
# Processing Record 10 of Set 14 | tynda
# Processing Record 11 of Set 14 | juneau
# Processing Record 12 of Set 14 | uige
# Processing Record 13 of Set 14 | valley
# Processing Record 14 of Set 14 | tingrela
# City not found. Skipping...
# Processing Record 15 of Set 14 | gorgan
# Processing Record 16 of Set 14 | maloye verevo
# Processing Record 17 of Set 14 | perth
# Processing Record 18 of Set 14 | los llanos de aridane
# Processing Record 19 of Set 14 | belaya gora
# Processing Record 20 of Set 14 | budogoshch
# Processing Record 21 of Set 14 | bondoukou
# Processing Record 22 of Set 14 | ostrovnoy
# Processing Record 23 of Set 14 | porto novo
# Processing Record 24 of Set 14 | tutoia
# Processing Record 25 of Set 14 | morris
# Processing Record 26 of Set 14 | brusyliv
# Processing Record 27 of Set 14 | platteville
# Processing Record 28 of Set 14 | aykhal
# Processing Record 29 of Set 14 | yaan
# Processing Record 30 of Set 14 | catalina
# Processing Record 31 of Set 14 | avila
# Processing Record 32 of Set 14 | kieta
# Processing Record 33 of Set 14 | bobo dioulasso
# Processing Record 34 of Set 14 | umm kaddadah
# Processing Record 35 of Set 14 | beloha
# Processing Record 36 of Set 14 | safaga
# Processing Record 37 of Set 14 | zilair
# Processing Record 38 of Set 14 | labuhan
# Processing Record 39 of Set 14 | stabat
# Processing Record 40 of Set 14 | redlands
# Processing Record 41 of Set 14 | merauke
# Processing Record 42 of Set 14 | strezhevoy
# Processing Record 43 of Set 14 | ranong
# Processing Record 44 of Set 14 | malynivka
# Processing Record 45 of Set 14 | mehamn
# Processing Record 46 of Set 14 | pekan
# Processing Record 47 of Set 14 | mbandaka
# Processing Record 48 of Set 14 | severo-yeniseyskiy
# Processing Record 49 of Set 14 | la union
# Processing Record 50 of Set 14 | bull savanna
# Processing Record 1 of Set 15 | ferme-neuve
# Processing Record 2 of Set 15 | santiago de cao
# Processing Record 3 of Set 15 | zhaoqing
# Processing Record 4 of Set 15 | staryy nadym
# Processing Record 5 of Set 15 | bestobe
# Processing Record 6 of Set 15 | novyy urgal
# Processing Record 7 of Set 15 | sheltozero
# Processing Record 8 of Set 15 | porbandar
# Processing Record 9 of Set 15 | narbonne
# Processing Record 10 of Set 15 | taiyuan
# Processing Record 11 of Set 15 | batemans bay
# Processing Record 12 of Set 15 | hirado
# Processing Record 13 of Set 15 | almaznyy
# Processing Record 14 of Set 15 | kiunga
# Processing Record 15 of Set 15 | mango
# Processing Record 16 of Set 15 | baruun-urt
# Processing Record 17 of Set 15 | the valley
# Processing Record 18 of Set 15 | marsa matruh
# Processing Record 19 of Set 15 | batsfjord
# Processing Record 20 of Set 15 | xuanzhou
# Processing Record 21 of Set 15 | verkhnyaya toyma
# Processing Record 22 of Set 15 | lompoc
# Processing Record 23 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 15 | querecotillo
# Processing Record 25 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 15 | preeceville
# Processing Record 27 of Set 15 | sindhnur
# Processing Record 28 of Set 15 | imbituba
# Processing Record 29 of Set 15 | necochea
# Processing Record 30 of Set 15 | salamanca
# Processing Record 31 of Set 15 | balangiga
# Processing Record 32 of Set 15 | kansanshi
# Processing Record 33 of Set 15 | tomigusuku
# Processing Record 34 of Set 15 | juruti
# Processing Record 35 of Set 15 | lazarev
# Processing Record 36 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 37 of Set 15 | konstantinovka
# Processing Record 38 of Set 15 | pierre
# Processing Record 39 of Set 15 | port-cartier
# Processing Record 40 of Set 15 | tiznit
# Processing Record 41 of Set 15 | saint-denis
# Processing Record 42 of Set 15 | tha chang
# Processing Record 43 of Set 15 | portsmouth
# Processing Record 44 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 15 | filingue
# Processing Record 46 of Set 15 | luangwa
# Processing Record 47 of Set 15 | havelock
# Processing Record 48 of Set 15 | ler
# Processing Record 49 of Set 15 | egvekinot
# Processing Record 50 of Set 15 | mutoko
# Processing Record 1 of Set 16 | sao joao da barra
# Processing Record 2 of Set 16 | san carlos de bariloche
# Processing Record 3 of Set 16 | avera
# Processing Record 4 of Set 16 | puerto cortes
# City not found. Skipping...
# Processing Record 5 of Set 16 | poltavka
# Processing Record 6 of Set 16 | buala
# Processing Record 7 of Set 16 | pontian kecil
# Processing Record 8 of Set 16 | catia la mar
# Processing Record 9 of Set 16 | hvittingfoss
# Processing Record 10 of Set 16 | linqiong
# Processing Record 11 of Set 16 | riwaka
# Processing Record 12 of Set 16 | wanaka
# Processing Record 13 of Set 16 | cap malheureux
# Processing Record 14 of Set 16 | bakchar
# Processing Record 15 of Set 16 | hervey bay
# Processing Record 16 of Set 16 | moose factory
# Processing Record 17 of Set 16 | chateaubelair
# Processing Record 18 of Set 16 | mumbwa
# Processing Record 19 of Set 16 | werda
# Processing Record 20 of Set 16 | khamgaon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cidreira      BR -30.1811  -50.2056     81.25        51           0
# 1    Valparaiso      CL -33.0393  -71.6273     70.52        70           3
# 2    Nelson Bay      AU -32.7167  152.1500     71.01        67          76
# 3  Ingraj Bazar      IN  25.0000   88.1500     60.26        64           5
# 4   New Norfolk      AU -42.7826  147.0587     52.72        74           4
# 5     Lexington      US  37.9887  -84.4777     45.34        52           0
# 6        Muroto      JP  33.2833  134.1500     40.28        55          22
# 7       Rucphen      NL  51.5317    4.5583     44.64        86          75
# 8       Qaanaaq      GL  77.4840  -69.3632    -12.60        58          32
# 9       Rikitea      PF -23.1203 -134.9692     79.09        70           2
#
#    Wind Speed Current Description
# 0       11.86           clear sky
# 1        9.60           clear sky
# 2        3.00       broken clouds
# 3        1.52           clear sky
# 4        1.95           clear sky
# 5       11.50           clear sky
# 6        9.75          few clouds
# 7        5.99       broken clouds
# 8        8.34    scattered clouds
# 9       16.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
